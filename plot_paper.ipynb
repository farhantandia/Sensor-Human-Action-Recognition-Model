# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from numpy import random

# %%
import numpy as np
import pandas as pd
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()
ts.plot()
plt.show()

# %%
df = pd.DataFrame(random.randn(1000, 4), index=ts.index, columns=list('ABCD'))

# %%
df = df.cumsum()

# %%
import copy
    
interesting_dir = "./Data/Fastest/"
#interesting_files = ["sit.csv", "stand.csv", "walk.csv"]
interesting_labels = ['stand', 'walk','jump','fall']
save_filename = "activity"
df = pd.DataFrame()
for i in range(len(interesting_labels)):
#     df_tmp = pd.read_csv(interesting_dir+save_filename+"_"+str(i+1)+'.csv',parse_dates=[['DATE', ' TIME']],header = 0)
    df_tmp = pd.read_csv(interesting_dir+save_filename+"_"+interesting_labels[i]+'.csv',header = 0)
    df = pd.concat([df, df_tmp])
    
print(len(df.columns))
# df['ts'] = df[['DATE_TIME']].apply(lambda x: x[0].timestamp(), axis=1).astype(int)
# df = df.assign(DATE_TIME=df['ts'])
# if len(df.columns) == 19 :
drop_list = ['DATE','TIME','mg','ma']
# else :pass

# drop_list = ['DATE','TIME','ma','mg']
df = df.drop(drop_list, axis=1)
df = df.dropna()

# df.rename(columns = {'DATE_TIME':'ts'}, inplace = True) 
all_data_filename = "total.csv"
df.to_csv(interesting_dir+all_data_filename)

# df.reset_index(inplace = True) 
df
# Out:
# 11
#              ax        ay        az        gx        gy        gz  label
# 0      9.592826  2.708675  0.942772 -0.007327  0.045181 -0.400524  stand
# 1      9.592826  2.708675  0.942772 -0.050066  0.036633 -0.433494  stand
# 2      9.463613  2.718246  0.942772 -0.050066  0.036633 -0.433494  stand
# 3      9.463613  2.718246  0.942772 -0.051287  0.026864 -0.417620  stand
# 4      9.348758  2.675176  0.978664 -0.051287  0.026864 -0.417620  stand
# ...         ...       ...       ...       ...       ...       ...    ...
# 15995 -1.533799  0.641277  8.563912  0.768079 -0.536068  0.829134   fall
# 15996 -1.469193  0.636491  8.702696  0.768079 -0.536068  0.829134   fall
# 15997 -1.469193  0.636491  8.702696  0.638641 -0.700918  0.799828   fall
# 15998 -1.227518  0.701097  8.896515  0.638641 -0.700918  0.799828   fall
# 15999 -1.227518  0.701097  8.896515  0.446927 -0.732667  0.736330   fall
#
# [64000 rows x 7 columns]

# %%
data_for_acc= df[(df['label'] == 'fall')][9000:9450]

# %%
plt.figure(dpi=80)

data_for_acc[['ax','ay','az']].plot(figsize=(18, 6))
plt.grid(True)
plt.xlabel('timestamp',size=20)
plt.ylabel('m/s2',size=20)
plt.title("Falling-Accelerometer",size=30)
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.legend(loc=2,fontsize=20)

# %%
plt.figure(dpi=80)

data_for_acc[['gx','gy','gz']].plot(figsize=(18, 6))
plt.grid(True)
plt.xlabel('timestamp',size=20)
plt.ylabel('rad/s',size=20)
plt.title("Falling-Gyroscope",size=30)
# plt.legend.size(20)
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.legend(loc=3,fontsize=20)

# %%
data_for_acc= df[(df['label'] == 'stand')][9100:9400]

# %%
plt.figure(dpi=80)

data_for_acc[['ax','ay','az']].plot(figsize=(18, 6))
plt.grid(True)
plt.xlabel('timestamp',size=20)
plt.ylabel('m/s2',size=20)
plt.title("Standing-Accelerometer",size=30)
# plt.legend.size(20)
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.legend(loc='best',fontsize=20)

# %%
plt.figure(dpi=80)

data_for_acc[['gx','gy','gz']].plot(figsize=(18, 6))
plt.grid(True)
plt.xlabel('timestamp',size=20)
plt.ylabel('rad/s',size=20)
plt.title("Standing-Gyroscope",size=30)
# plt.legend.size(20)
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.legend(loc=1,fontsize=20)

# %%
data_for_acc= df[(df['label'] == 'walk')][8000:9750]

plt.figure(dpi=80)

data_for_acc[['ax','ay','az']].plot(figsize=(18, 6))
plt.grid(True)
plt.xlabel('timestamp',size=20)
plt.ylabel('m/s2',size=20)
plt.title("Walking-Accelerometer",size=30)
# plt.legend.size(20)
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.legend(loc=1,fontsize=20)

plt.figure(dpi=80)

data_for_acc[['gx','gy','gz']].plot(figsize=(18, 6))
plt.grid(True)
plt.xlabel('timestamp',size=20)
plt.ylabel('rad/s',size=20)
plt.title("Walking-Gyroscope",size=30)
# plt.legend.size(20)
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.legend(loc=1,fontsize=20)

# %%
data_for_acc= df[(df['label'] == 'jump')][8000:9750]

plt.figure(dpi=80)

data_for_acc[['ax','ay','az']].plot(figsize=(18, 6))
plt.grid(True)
plt.xlabel('timestamp',size=20)
plt.ylabel('m/s2',size=20)
plt.title("Jumping-Accelerometer",size=30)
# plt.legend.size(20)
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.legend(loc=3,fontsize=20)

plt.figure(dpi=80)

data_for_acc[['gx','gy','gz']].plot(figsize=(18, 6))
plt.grid(True)
plt.xlabel('timestamp',size=20)
plt.ylabel('rad/s',size=20)
plt.title("Jumping-Gyroscope",size=30)
# plt.legend.size(20)
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.legend(loc=3,fontsize=20)
